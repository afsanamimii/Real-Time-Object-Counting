# %%
import cv2
import numpy as np

# %%
net=cv2.dnn.readNet(r"C:\Users\Asus\yolov3.weights",r"C:\Users\Asus\yolov3.cfg")

# %%
classes=[]

# %%
with open('coco.names','r') as f:
    classes=f.read().splitlines()

# %%
def countobject(whole_track_list,index_of_track):
    count=0
    for p in whole_track_list:
        
            
            if(p==index_of_track):
                
                count+=1
    return count

# %%
def numOfsameIndex(whole_redundant_list,item_id):
    count1=0
    for q in whole_redundant_list:
        if(q==item_id):
            count1+=1
    return count1

# %%
#backup and final

# %%
def videowrite(receivedsize):
    
    i=0
    x=20
    y=30
    while i<receivedsize:
        
        label=str(classes[redundant[i]])
        cv2.putText(img,label,(x,y),cv2.FONT_HERSHEY_SIMPLEX,1,(255,0,0),1)
        x+=180
        text=":{}".format(countlists[i])
        cv2.putText(img,text,(x,y),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,255),1)
        i+=1
        x=x-180
        y+=30

# %%
cap=cv2.VideoCapture(0)
while True:
    ret,img=cap.read()
    #print("ret value",ret)
    #print("frmae value",img)
    fps=cap.get(cv2.CAP_PROP_FPS)
    #print("fps:{}".format(fps))
    
    
    
    raw_height,raw_width, _ =img.shape
    blob=cv2.dnn.blobFromImage(img,1/255,(416,416),(0,0,0),swapRB=True,crop=False)
    net.setInput(blob)
    
    output_layers_names=net.getUnconnectedOutLayersNames()
    finaloutputs=net.forward(output_layers_names)
    boxes_no=[]
    confidences_score=[]
    class_ids=[]
    for outputs in finaloutputs:
        for detect in outputs:
            scores=detect[5:]
            class_id=np.argmax(scores)
            confidence=scores[class_id]
            if confidence > 0.7:
                x_center=int(detect[0]*raw_width)
                y_center=int(detect[1]*raw_height)
                w=int(detect[2]*raw_width)
                h=int(detect[3]*raw_height)
            
                x=int(x_center-w/2)
                y=int(y_center-h/2)
                boxes_no.append([x,y,w,h])
                confidences_score.append((float(confidence)))
                class_ids.append(class_id)
        
    #print(len(boxes_no))   
    index=cv2.dnn.NMSBoxes(boxes_no,confidences_score,0.7,0.4)
    
    colors=np.random.uniform(0,255,size=(len(boxes_no),3))
    track=[]
    if len(index)>0: 
        
        for l in index.flatten():
            
        
            x,y,w,h=boxes_no[l]
            label=str(classes[class_ids[l]])
            #print(class_ids[i])
            track.append(class_ids[l])
            confidence=str(round(confidences_score[l],2))
            color=colors[l]
            cv2.rectangle(img,(x,y),(x+w,y+h),color,2)
            cv2.putText(img,label+" "+confidence,(x,y+10),cv2.FONT_HERSHEY_SIMPLEX,1,(255,0,255),1)
    
    
    
    print("values in track list",track)
    
    redundant=[]
    countlists=[]
    size=len(track)



    i=0
    while i<size:
        
    
        redundantsize=len(redundant)
    
        if (redundantsize==0):
            
            totalobject=countobject(track,track[i])
            #print("lenth of redundant array",redundantsize)
            #print("value",redundant)
        
            redundant.append(track[i])
            countlists.append(totalobject)
            i+=1
        
        else:
            rslt=numOfsameIndex(redundant,track[i])
        
            if(rslt==0):
                totalobject=countobject(track,track[i])
                #print("lenth of redundant array",redundantsize)
               # print("value",redundant)
                redundant.append(track[i])
                countlists.append(totalobject)
                i+=1
            else:
                i+=1
            
        
            
    
    
        
        
        
        
    
    


    loopsize=len(countlists)
    #print("loopsize",loopsize)
    videowrite(loopsize)           
    cv2.imshow('Image',img)
    if cv2.waitKey(1) & 0xFF ==ord("q"):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list []
# values in track list [61]
# values in track list [39]
# values in track list []
# values in track list [39, 41, 47]
# values in track list [39, 41, 41]
# values in track list [39, 41, 41, 47]
# values in track list [39, 41, 39, 41, 0]
# values in track list [39, 39, 41, 0, 24]
# values in track list [39, 39, 41, 24]
# values in track list [39, 41, 0, 24]
# values in track list [39, 41, 0, 39, 24]
# values in track list [39, 41, 24, 0]
# values in track list [39, 39, 41, 0, 24]
# values in track list [39, 39, 41, 24, 0]
# values in track list [39, 39, 41, 24]
# values in track list [39, 39, 41, 24]
# values in track list [39, 39, 41, 24]
# values in track list [39, 41, 24, 0, 39]
# values in track list [39, 41, 24]
# values in track list [39, 41]
# values in track list [39, 41, 24]
# values in track list [39, 41, 24]
# values in track list [39, 41, 24, 39]
# values in track list [39, 39, 41, 24, 0]
# values in track list [39, 41]
# values in track list [39, 39, 41, 24]
# values in track list [39, 39, 41, 24]
# values in track list [39, 39, 41, 24]
# values in track list [39, 39, 41, 24]
# values in track list [39, 39, 41, 41, 0, 24]
# values in track list [39, 41, 41, 39, 24]
# values in track list [39, 39, 41, 41, 24]
# values in track list [39, 39, 41, 41]
# values in track list [39, 41, 39, 41, 24]
# values in track list [39, 39, 41, 41, 47]
# values in track list [39, 41, 39, 41, 24]
# values in track list [41, 39, 39, 41, 47, 24]
# values in track list [39, 39, 41, 41, 47]
# values in track list [39, 39, 41, 41, 47]
# values in track list [39, 39, 41, 41, 47]
# values in track list [39, 41, 41, 47, 0, 39]
# values in track list [39, 41, 41, 47, 24]
# values in track list [41, 39, 24, 47, 41]
# values in track list [39, 41, 47]
# values in track list [41, 39, 41, 60, 47, 24]
# values in track list [39, 41, 41, 24]
# values in track list [39, 41, 41, 24]
# values in track list [39, 41, 41, 24]
# values in track list [39, 41, 41]
# values in track list []
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list []
# values in track list []
# values in track list [0]
# values in track list [0]
# values in track list []
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
# values in track list [0]
